# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 605

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url="http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
city_data=[]


print("starting_api_calls")
print("-----------------------------")

record_count=1
set_count=1



for i, city in enumerate(cities):
    #print("this_is_city: " + city)
    #print("this is i: " + str(i)) 
    city_url = url + "&q=" + city
    #print (city_url)
    try:
        city_weather = requests.get(city_url).json()
        city_latitude = city_weather["coord"]["lat"]
        city_lon = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_country = city_weather["sys"]["country"]
        city_wind = city_weather["wind"]["speed"]
        city_date = city_weather["dt"]
        
        city_data.append({"City": city, 
                          "Lat": city_latitude,
                          "Lon": city_lon,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Country": city_country,
                          "Wind Speed": city_wind,
                          "Date": city_date})
        print("Finished city: " + city)
        
    except:
        print("city not found...")
        pass

    
    
print("finished api request")
# Out:
# starting_api_calls
# -----------------------------
# Finished city: mogadishu
# Finished city: atuona
# Finished city: kaitangata
# Finished city: markova
# city not found...
# Finished city: hermanus
# Finished city: mezen
# Finished city: gorontalo
# Finished city: tazovskiy
# Finished city: boyolangu
# Finished city: punta arenas
# Finished city: huntsville
# Finished city: tiksi
# Finished city: mar del plata
# Finished city: saint-philippe
# Finished city: tuktoyaktuk
# Finished city: solnechnyy
# Finished city: kroya
# Finished city: grand gaube
# Finished city: ushuaia
# Finished city: harpanahalli
# Finished city: chumikan
# Finished city: rikitea
# Finished city: port hedland
# city not found...
# Finished city: salur
# Finished city: neubrandenburg
# Finished city: kapaa
# Finished city: bluff
# Finished city: vila velha
# Finished city: sur
# Finished city: port alfred
# Finished city: dikson
# Finished city: vaini
# Finished city: nhulunbuy
# Finished city: akdepe
# Finished city: namibe
# Finished city: puerto escondido
# Finished city: llata
# city not found...
# Finished city: hambantota
# Finished city: barrow
# Finished city: provideniya
# Finished city: mitchell
# city not found...
# Finished city: albany
# city not found...
# Finished city: henties bay
# Finished city: kavieng
# Finished city: hobart
# Finished city: hami
# Finished city: tessalit
# city not found...
# Finished city: santa rosa
# Finished city: kahului
# Finished city: sao joao da barra
# Finished city: lorengau
# Finished city: mataura
# Finished city: bredasdorp
# city not found...
# Finished city: bluefield
# Finished city: hithadhoo
# Finished city: bengkulu
# Finished city: bethel
# Finished city: vila franca do campo
# Finished city: sibu
# Finished city: port lincoln
# Finished city: nome
# Finished city: longyearbyen
# Finished city: aras
# Finished city: pedasi
# Finished city: port-cartier
# city not found...
# Finished city: lompoc
# Finished city: butaritari
# Finished city: busselton
# Finished city: brigantine
# Finished city: constitucion
# Finished city: bucerias
# Finished city: tyumentsevo
# city not found...
# Finished city: leningradskiy
# city not found...
# Finished city: villa maria
# Finished city: masvingo
# Finished city: kawalu
# city not found...
# Finished city: gouyave
# Finished city: ribeira grande
# Finished city: torbay
# Finished city: fortuna
# Finished city: stornoway
# Finished city: hamilton
# Finished city: khaga
# Finished city: hirado
# Finished city: castro
# Finished city: casablanca
# city not found...
# Finished city: encheng
# city not found...
# Finished city: sao filipe
# Finished city: bilibino
# Finished city: luderitz
# Finished city: georgetown
# Finished city: lata
# Finished city: kruisfontein
# Finished city: drumheller
# Finished city: tasiilaq
# Finished city: quatre cocos
# Finished city: gallup
# Finished city: pacific grove
# Finished city: cape town
# Finished city: abu samrah
# Finished city: nikolskoye
# Finished city: thompson
# Finished city: saint-pierre
# city not found...
# Finished city: puerto ayora
# Finished city: poum
# Finished city: ancud
# Finished city: jamestown
# Finished city: tuatapere
# Finished city: new norfolk
# Finished city: kilosa
# Finished city: kaniama
# Finished city: codrington
# Finished city: mineros
# Finished city: hervey bay
# Finished city: lagoa
# Finished city: atambua
# Finished city: flinders
# Finished city: aklavik
# Finished city: avarua
# Finished city: krasnoselkup
# city not found...
# Finished city: crotone
# Finished city: pangoa
# Finished city: cabedelo
# Finished city: aquiraz
# Finished city: mokhsogollokh
# Finished city: ust-ishim
# Finished city: hilo
# Finished city: kenai
# Finished city: udachnyy
# Finished city: dalian
# Finished city: mao
# Finished city: batemans bay
# Finished city: mwingi
# Finished city: waldkirchen
# Finished city: qaanaaq
# Finished city: vila
# Finished city: timbiqui
# Finished city: taoudenni
# Finished city: kodiak
# Finished city: sechura
# Finished city: billings
# Finished city: kalmunai
# Finished city: yellowknife
# Finished city: phan thiet
# Finished city: margate
# Finished city: manjakandriana
# Finished city: mildura
# Finished city: zaysan
# Finished city: kaspiysk
# Finished city: ust-kuyga
# Finished city: sistranda
# city not found...
# Finished city: mahebourg
# Finished city: airai
# Finished city: lubbock
# Finished city: olafsvik
# Finished city: ponta do sol
# Finished city: hat yai
# Finished city: caravelas
# Finished city: fukue
# Finished city: vardo
# Finished city: severo-kurilsk
# Finished city: port elizabeth
# Finished city: ramygala
# Finished city: kabinda
# Finished city: pevek
# Finished city: mount isa
# Finished city: omboue
# Finished city: pisco
# Finished city: bulgan
# Finished city: cayenne
# Finished city: arraial do cabo
# Finished city: kuryk
# Finished city: cabo san lucas
# Finished city: ginda
# Finished city: guerrero negro
# Finished city: zhezkazgan
# Finished city: iqaluit
# Finished city: lardos
# Finished city: clyde river
# Finished city: huaihua
# Finished city: veseloyarsk
# Finished city: erzin
# Finished city: hargeysa
# Finished city: touros
# Finished city: dargaville
# Finished city: kodinsk
# city not found...
# Finished city: ambon
# Finished city: vestmannaeyjar
# Finished city: imeni babushkina
# city not found...
# Finished city: mount gambier
# Finished city: buraydah
# Finished city: tselina
# city not found...
# city not found...
# Finished city: souillac
# Finished city: santa marta de tormes
# Finished city: mutis
# Finished city: kiunga
# Finished city: ponta delgada
# Finished city: altay
# Finished city: east london
# Finished city: norman wells
# Finished city: niono
# Finished city: zelenoborsk
# Finished city: denia
# Finished city: hay river
# Finished city: fairbanks
# Finished city: tura
# Finished city: malanje
# Finished city: ustikolina
# city not found...
# Finished city: aswan
# Finished city: kedrovyy
# Finished city: kerema
# Finished city: nago
# Finished city: samfya
# Finished city: calvinia
# Finished city: venice
# Finished city: klaksvik
# Finished city: grao mogol
# Finished city: los alamos
# Finished city: piacenza
# Finished city: tyulyachi
# Finished city: ingham
# Finished city: peleduy
# Finished city: coolum beach
# Finished city: jinxiang
# Finished city: geraldton
# Finished city: chokurdakh
# city not found...
# Finished city: aygedzor
# Finished city: zilair
# Finished city: hun
# Finished city: san nicolas
# Finished city: san cristobal
# Finished city: jurm
# Finished city: praia
# Finished city: forio
# Finished city: kichera
# Finished city: upernavik
# Finished city: urucui
# Finished city: nelson bay
# Finished city: katsuura
# city not found...
# Finished city: chuy
# Finished city: sinnamary
# Finished city: taksimo
# Finished city: san carlos de bariloche
# Finished city: santa isabel do rio negro
# Finished city: saskylakh
# Finished city: nanzhang
# Finished city: santa lucia
# Finished city: khatanga
# city not found...
# city not found...
# Finished city: faanui
# Finished city: carnarvon
# Finished city: maragogi
# city not found...
# Finished city: honiara
# Finished city: ayagoz
# Finished city: bugama
# Finished city: husavik
# Finished city: pontianak
# Finished city: nizwa
# Finished city: sorland
# Finished city: manyana
# Finished city: great falls
# Finished city: samarai
# Finished city: pychas
# Finished city: bauchi
# Finished city: maldonado
# Finished city: rosario
# Finished city: rawlins
# city not found...
# Finished city: bridgetown
# Finished city: cherskiy
# Finished city: urumqi
# Finished city: pokhara
# Finished city: helong
# Finished city: talnakh
# Finished city: labuhan
# Finished city: harper
# Finished city: itarema
# Finished city: zhigansk
# Finished city: lebu
# Finished city: xinmin
# Finished city: atherton
# Finished city: west bay
# Finished city: zonguldak
# Finished city: deputatskiy
# Finished city: murgab
# Finished city: pangnirtung
# city not found...
# Finished city: nantucket
# Finished city: bar harbor
# Finished city: joniskis
# Finished city: san patricio
# Finished city: idar
# Finished city: hatfield
# Finished city: broome
# Finished city: komsomolskiy
# Finished city: hasaki
# Finished city: arman
# Finished city: cananeia
# Finished city: pilar
# Finished city: hovd
# Finished city: victoria
# Finished city: rudbar
# Finished city: kaka
# Finished city: taltal
# Finished city: birjand
# Finished city: mugur-aksy
# Finished city: yar-sale
# Finished city: fort payne
# Finished city: perth
# Finished city: eureka
# Finished city: oga
# city not found...
# Finished city: moron
# Finished city: sakaiminato
# Finished city: atar
# Finished city: benghazi
# Finished city: ternate
# Finished city: manono
# Finished city: kavaratti
# Finished city: yatou
# Finished city: namatanai
# Finished city: agadez
# Finished city: haines junction
# Finished city: bagotville
# Finished city: chernyshevskiy
# Finished city: narsaq
# Finished city: saldanha
# Finished city: smithers
# Finished city: sakakah
# Finished city: nanortalik
# Finished city: te anau
# Finished city: igurusi
# Finished city: bedford
# city not found...
# Finished city: berlevag
# Finished city: cuenca
# Finished city: grindavik
# Finished city: fuengirola
# Finished city: egvekinot
# Finished city: tadine
# Finished city: rio gallegos
# Finished city: ixtapa
# Finished city: rocha
# Finished city: sitka
# Finished city: taywarah
# Finished city: lichuan
# Finished city: boa vista
# Finished city: shimoda
# Finished city: bambous virieux
# Finished city: tevriz
# Finished city: vaitape
# Finished city: lazaro cardenas
# Finished city: powell river
# Finished city: esperance
# Finished city: bundaberg
# Finished city: alofi
# Finished city: taybad
# Finished city: doka
# Finished city: longview
# Finished city: kyshtovka
# Finished city: bainbridge
# Finished city: springbok
# Finished city: turukhansk
# Finished city: maun
# Finished city: minbu
# Finished city: vilyuysk
# Finished city: asau
# Finished city: saravena
# Finished city: praia da vitoria
# Finished city: faya
# Finished city: mweka
# Finished city: llanes
# Finished city: walvis bay
# Finished city: saint george
# Finished city: eydhafushi
# Finished city: kjollefjord
# Finished city: auki
# Finished city: jammalamadugu
# Finished city: bangkalan
# city not found...
# Finished city: soller
# Finished city: jalor
# Finished city: itaituba
# Finished city: nizhniy tsasuchey
# Finished city: brae
# Finished city: virginia beach
# Finished city: rundu
# Finished city: kattivakkam
# Finished city: marystown
# Finished city: piriyapatna
# city not found...
# Finished city: manokwari
# Finished city: tiznit
# Finished city: ayan
# Finished city: vila do maio
# city not found...
# Finished city: valley city
# Finished city: acapulco
# Finished city: gaogou
# Finished city: anloga
# Finished city: san roque
# city not found...
# Finished city: listvyanskiy
# Finished city: tunoshna
# city not found...
# Finished city: kulhudhuffushi
# Finished city: salalah
# Finished city: roma
# Finished city: baruun-urt
# Finished city: flin flon
# Finished city: ludvika
# city not found...
# Finished city: dunmore town
# Finished city: bolshaya dzhalga
# Finished city: hualmay
# Finished city: ereymentau
# Finished city: mayo
# Finished city: champerico
# Finished city: ahuimanu
# Finished city: telde
# Finished city: vrangel
# Finished city: terney
# Finished city: calintaan
# Finished city: merauke
# Finished city: bac lieu
# Finished city: xining
# city not found...
# Finished city: fernie
# Finished city: ranong
# Finished city: fare
# Finished city: saint-leu
# Finished city: kirakira
# Finished city: kushima
# Finished city: yaan
# Finished city: takoradi
# Finished city: pirapora do bom jesus
# Finished city: kamenka
# Finished city: carauari
# Finished city: magadan
# Finished city: lima
# Finished city: buzmeyin
# Finished city: kiruna
# Finished city: yeniseysk
# Finished city: piacabucu
# Finished city: ostrovnoy
# Finished city: sebastian
# Finished city: manta
# Finished city: molchanovo
# Finished city: marsa matruh
# Finished city: burns lake
# Finished city: svetlogorsk
# Finished city: goderich
# Finished city: beringovskiy
# Finished city: gasa
# Finished city: salym
# Finished city: senanga
# Finished city: tucuman
# Finished city: cozumel
# Finished city: zlobin
# Finished city: gorin
# Finished city: kargasok
# Finished city: ekibastuz
# Finished city: college
# Finished city: vao
# Finished city: baiyin
# Finished city: wanning
# Finished city: lavrentiya
# Finished city: ajaccio
# Finished city: paamiut
# city not found...
# Finished city: gioia tauro
# Finished city: isangel
# Finished city: eyl
# Finished city: panzhihua
# Finished city: barbate
# Finished city: murwillumbah
# Finished city: bukama
# Finished city: melilla
# Finished city: bathsheba
# Finished city: rantauprapat
# Finished city: saint-augustin
# Finished city: maple creek
# Finished city: tarrega
# Finished city: tacuarembo
# Finished city: kuruman
# Finished city: panguna
# Finished city: pirovskoye
# Finished city: turochak
# Finished city: ketchikan
# Finished city: kaseda
# Finished city: san miguel
# Finished city: lannion
# Finished city: biak
# Finished city: ilebo
# Finished city: chittaurgarh
# Finished city: port blair
# Finished city: half moon bay
# Finished city: mongu
# Finished city: agadir
# Finished city: owando
# Finished city: dauphin
# Finished city: nogales
# Finished city: saquena
# Finished city: bollnas
# Finished city: vuktyl
# Finished city: bilma
# Finished city: la ronge
# Finished city: chikwawa
# Finished city: launceston
# Finished city: tomatlan
# city not found...
# Finished city: tshikapa
# Finished city: karasjok
# Finished city: paso de los toros
# Finished city: tera
# Finished city: jalu
# Finished city: saint-francois
# Finished city: buta
# Finished city: morro bay
# Finished city: nioro
# Finished city: batangafo
# Finished city: belluru
# Finished city: cockburn town
# city not found...
# Finished city: pinega
# Finished city: westport
# Finished city: smirnykh
# Finished city: baie-comeau
# Finished city: matara
# city not found...
# Finished city: bartica
# Finished city: carai
# Finished city: abha
# Finished city: cheremukhovo
# Finished city: coruripe
# Finished city: tautira
# Finished city: sakskobing
# Finished city: alihe
# Finished city: canico
# Finished city: juneau
# Finished city: stonewall
# Finished city: buala
# Finished city: rawson
# Finished city: maniitsoq
# Finished city: port hardy
# Finished city: angoche
# Finished city: kurumkan
# Finished city: irbit
# Finished city: tomohon
# Finished city: porto novo
# Finished city: mujiayingzi
# Finished city: sakhnovshchyna
# Finished city: kuching
# city not found...
# Finished city: cidreira
# city not found...
# Finished city: makakilo city
# Finished city: igunga
# Finished city: lanzhou
# Finished city: green river
# Finished city: tefe
# Finished city: port victoria
# Finished city: anadyr
# Finished city: bandarbeyla
# city not found...
# Finished city: winslow
# Finished city: salmo
# Finished city: luanda
# Finished city: riyadh
# Finished city: charleston
# Finished city: proletarsk
# Finished city: khromtau
# Finished city: yerbogachen
# Finished city: hobyo
# Finished city: menongue
# Finished city: lunsar
# city not found...
# Finished city: cavalcante
# Finished city: yambio
# Finished city: babu
# finished api request

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.count()
# Out:
# City          560
# Lat           560
# Lon           560
# Max Temp      560
# Humidity      560
# Cloudiness    560
# Country       560
# Wind Speed    560
# Date          560
# dtype: int64

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
